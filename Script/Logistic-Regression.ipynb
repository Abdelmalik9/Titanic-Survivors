# %% [markdown]
# # Libraries, directory and data

# %%
# %cd C:\Users\ASUS\Desktop\Business Analyst course\Statistics and Descriptive Analytics\Logistic Regression
# Out:
# C:\Users\ASUS\Desktop\Business Analyst course\Statistics and Descriptive Analytics\Logistic Regression

# %%
#libraries 
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
#load the data
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# # Data Analysis

# %%
#histograms
df.hist(figsize= (15,10))
# Out:
# array([[<Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Siblings/Spouses Aboard'}>],
#        [<Axes: title={'center': 'Parents/Children Aboard'}>,
#         <Axes: title={'center': 'Fare'}>]], dtype=object)

# %%
#Drop name variable
df = df.drop(columns = "Name")
df.head(1)
# Out:
#    Survived  Pclass   Sex   Age  Siblings/Spouses Aboard  \
# 0         0       3  male  22.0                        1
#
#    Parents/Children Aboard  Fare
# 0                        0  7.25

# %%
#Transform character variables
df = pd.get_dummies(data = df, drop_first = True,sparse=False,dtype=int)

# %%
#Correlation matrix
plt.figure(figsize = (8,6))
sns.set(font_scale=1.5)
sns.heatmap(df.corr(),
            annot = True,
            fmt = '.1g',
            center = 0,
            cmap = 'coolwarm',
            linewidths = 1,
            linecolor = 'black')
# Out:
# <Axes: >

# %% [markdown]
# # Logistic Regression preparation

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, Siblings/Spouses Aboard, Parents/Children Aboard, Fare, Sex_male]
# Index: []

# %%
#Prepare X and Y
y = df.Survived
X = df.drop(columns = "Survived")
X = sm.add_constant(X)

# %%
#Training and Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2,
                                                    random_state = 1502)
X_train.head(2)
# Out:
#      const  Pclass   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 457    1.0       1  48.0                        0                        0
# 331    1.0       3  16.0                        2                        0
#
#       Fare  Sex_male
# 457  26.55         1
# 331  18.00         1

# %% [markdown]
# # Logistic Regression and Assessment

# %%
#Logistic Regression
model = sm.Logit(y_train, X_train).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.405125
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  709
# Model:                          Logit   Df Residuals:                      702
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 16 Jul 2025   Pseudo R-squ.:                  0.3915
# Time:                        06:40:43   Log-Likelihood:                -287.23
# converged:                       True   LL-Null:                       -472.06
# Covariance Type:            nonrobust   LLR p-value:                 9.247e-77
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
#predictions
predictions = model.predict(X_test)
predictions = np.where(predictions > 0.5, 1, 0)
predictions[:4]
# Out:
# array([1, 0, 0, 1])

# %%
#Confusion matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
# Out:
# [[84 24]
#  [26 44]]

# %%
#Accuracy
#Accuracy = (True positive + True negative ) / All
accuracy = (tp + tn) / (tp + tn + fp + fn)
print("Accuracy:", round(accuracy * 100, 1), "%")

#F1-Score
#F1-score = 2 * TP / (2 * TP + FP + FN)
F1 = 2 * tp / (2 * tp + fp + fn)
print("F1-Score:" , round(F1 * 100, 1), "%")

#Specificity or True Negative Rate
#True Negative / (True Negative + False Positive)
Specificity = tn / (tn + fp)
print("Specificity:", round(Specificity * 100, 1), "%")

#Sensitivity, Recall or True Positive Rate
#True Positive / (True Positive + False Negative)
Sensitivity = tp / (tp + fn)
print("Sensitivity:", round(Sensitivity * 100, 1), "%")
# Out:
# Accuracy: 71.9 %
# F1-Score: 63.8 %
# Specificity: 77.8 %
# Sensitivity: 62.9 %

# %%
#Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       108
#            1       0.65      0.63      0.64        70
#
#     accuracy                           0.72       178
#    macro avg       0.71      0.70      0.70       178
# weighted avg       0.72      0.72      0.72       178
